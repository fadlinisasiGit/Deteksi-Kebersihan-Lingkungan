# %%
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
# mengecek versi Tensorflow di Colab
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.20-py3-none-any.whl (14 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.62.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.20

# %%
# install paket kaggle
# !pip install -q kaggle

# Upload file kaggle.json dari Create New API Token Akun Kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-654b56fa-253c-418f-b4b3-737fb8b6ecd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-654b56fa-253c-418f-b4b3-737fb8b6ecd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"mfadliramadhan","key":"469324e883b64509a270edc4bfa15d4d"}'}

# %%
import opendatasets as od
dataset_url= 'https://www.kaggle.com/mfadliramadhan/cleandirtygarbage'
od.download('https://www.kaggle.com/mfadliramadhan/cleandirtygarbage')
# Out:
# Downloading cleandirtygarbage.zip to ./cleandirtygarbage
# 100%|██████████| 643M/643M [00:03<00:00, 194MB/s]

# %%
# melakukan ekstraksi pada file zip
import zipfile,os

 
base_dir = '/content/cleandirtygarbage/garbage'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

os.listdir('/content/cleandirtygarbage/garbage/train')
os.listdir('/content/cleandirtygarbage/garbage/test')
# Out:
# ['clean', 'dirty']

# %%
# Total seluruh data
train_clean = len(os.listdir('/content/cleandirtygarbage/garbage/train/clean'))
train_dirty = len(os.listdir('/content/cleandirtygarbage/garbage/train/dirty'))
test_clean = len(os.listdir('/content/cleandirtygarbage/garbage/test/clean'))
test_dirty = len(os.listdir('/content/cleandirtygarbage/garbage/test/dirty'))

print("count data: ")
print("train clean: " + str(train_clean))
print("train dirty: " + str(train_dirty))
print("train clean: " + str(test_clean))
print("test dirty: " + str(test_dirty))
print("total: "+ str(train_clean+train_dirty+test_clean+test_dirty))
# Out:
# count data:
# train clean: 1207
# train dirty: 1019
# train clean: 600
# test dirty: 600
# total: 3426

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest',
                    validation_split = 0.2)

test_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest',
                    validation_split = 0.2)

train_generator = train_datagen.flow_from_directory(
        train_dir,  # direktori data latih
        target_size=(150, 150),  # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4,
        # karena kita merupakan masalah klasifikasi 2 kelas maka menggunakan class_mode = 'binary'
        class_mode='binary',
        subset = 'training')

test_generator = test_datagen.flow_from_directory(
        test_dir, # direktori data validasi
        target_size=(150, 150), # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4, # karena kita merupakan masalah klasifikasi 2 kelas maka menggunakan class_mode = 'binary'
        class_mode='binary',
        subset = 'validation')
# Out:
# Found 1782 images belonging to 2 classes.
# Found 240 images belonging to 2 classes.

# %%
print(train_generator.class_indices)
# Out:
# {'clean': 0, 'dirty': 1}

# %%
# membangun arsitektur sebuah CNN
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dropout (Dropout)           (None, 57600)             0
#
#  dense (Dense)               (None, 512)               29491712
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 29,880,641
# Trainable params: 29,880,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9 and logs.get('val_accuracy')>0.9):
      print("\nTraining Model Stopped! Accuracy Model is above 90%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
# Optimizer dengan learning rate
from tensorflow.keras.optimizers import Adam

adam = Adam(lr=0.0001)

model.compile(loss = 'binary_crossentropy',
              optimizer = adam,
              metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(
      train_generator,  
      epochs=200, 
      steps_per_epoch=25,
      validation_data=test_generator,
      validation_steps=5, 
      verbose=2,
      callbacks=[callbacks])
# Out:
# Epoch 1/200
# 25/25 - 4s - loss: 0.3426 - accuracy: 0.8400 - val_loss: 0.6189 - val_accuracy: 0.7000 - 4s/epoch - 156ms/step
# Epoch 2/200
# 25/25 - 3s - loss: 0.4693 - accuracy: 0.7500 - val_loss: 0.5646 - val_accuracy: 0.6000 - 3s/epoch - 128ms/step
# Epoch 3/200
# 25/25 - 3s - loss: 0.3549 - accuracy: 0.8800 - val_loss: 0.2971 - val_accuracy: 0.9500 - 3s/epoch - 134ms/step
# Epoch 4/200
# 25/25 - 3s - loss: 0.4199 - accuracy: 0.8200 - val_loss: 0.3308 - val_accuracy: 0.8500 - 3s/epoch - 135ms/step
# Epoch 5/200
# 25/25 - 3s - loss: 0.4204 - accuracy: 0.8200 - val_loss: 0.7309 - val_accuracy: 0.6500 - 3s/epoch - 118ms/step
# Epoch 6/200
# 25/25 - 3s - loss: 0.5298 - accuracy: 0.7200 - val_loss: 0.4808 - val_accuracy: 0.8000 - 3s/epoch - 135ms/step
# Epoch 7/200
# 25/25 - 3s - loss: 0.3575 - accuracy: 0.8300 - val_loss: 0.3196 - val_accuracy: 0.9000 - 3s/epoch - 125ms/step
# Epoch 8/200
# 25/25 - 3s - loss: 0.3051 - accuracy: 0.8700 - val_loss: 0.7775 - val_accuracy: 0.6500 - 3s/epoch - 122ms/step
# Epoch 9/200
# 25/25 - 4s - loss: 0.2860 - accuracy: 0.8900 - val_loss: 0.4571 - val_accuracy: 0.7000 - 4s/epoch - 160ms/step
# Epoch 10/200
# 25/25 - 4s - loss: 0.3940 - accuracy: 0.8000 - val_loss: 0.3250 - val_accuracy: 0.7500 - 4s/epoch - 146ms/step
# Epoch 11/200
# 25/25 - 3s - loss: 0.4621 - accuracy: 0.7800 - val_loss: 0.2518 - val_accuracy: 0.9000 - 3s/epoch - 131ms/step
# Epoch 12/200
# 25/25 - 3s - loss: 0.3847 - accuracy: 0.8600 - val_loss: 0.1758 - val_accuracy: 0.9500 - 3s/epoch - 135ms/step
# Epoch 13/200
# 25/25 - 3s - loss: 0.2776 - accuracy: 0.8800 - val_loss: 0.6373 - val_accuracy: 0.7500 - 3s/epoch - 134ms/step
# Epoch 14/200
# 25/25 - 3s - loss: 0.4402 - accuracy: 0.7500 - val_loss: 0.3168 - val_accuracy: 0.8500 - 3s/epoch - 106ms/step
# Epoch 15/200
# 25/25 - 3s - loss: 0.4517 - accuracy: 0.7900 - val_loss: 0.4075 - val_accuracy: 0.8500 - 3s/epoch - 132ms/step
# Epoch 16/200
# 25/25 - 3s - loss: 0.4294 - accuracy: 0.7600 - val_loss: 0.6358 - val_accuracy: 0.8000 - 3s/epoch - 131ms/step
# Epoch 17/200
# 25/25 - 4s - loss: 0.3182 - accuracy: 0.8700 - val_loss: 0.3640 - val_accuracy: 0.8000 - 4s/epoch - 178ms/step
# Epoch 18/200
# 25/25 - 5s - loss: 0.3991 - accuracy: 0.8265 - val_loss: 0.4637 - val_accuracy: 0.8000 - 5s/epoch - 193ms/step
# Epoch 19/200
# 25/25 - 4s - loss: 0.3912 - accuracy: 0.8200 - val_loss: 0.2172 - val_accuracy: 0.9000 - 4s/epoch - 155ms/step
# Epoch 20/200
# 25/25 - 3s - loss: 0.3865 - accuracy: 0.8400 - val_loss: 0.3334 - val_accuracy: 0.8500 - 3s/epoch - 109ms/step
# Epoch 21/200
# 25/25 - 3s - loss: 0.4109 - accuracy: 0.8100 - val_loss: 0.6183 - val_accuracy: 0.7000 - 3s/epoch - 137ms/step
# Epoch 22/200
# 25/25 - 3s - loss: 0.3807 - accuracy: 0.8400 - val_loss: 0.5224 - val_accuracy: 0.7500 - 3s/epoch - 117ms/step
# Epoch 23/200
# 25/25 - 4s - loss: 0.3504 - accuracy: 0.8200 - val_loss: 0.4395 - val_accuracy: 0.8000 - 4s/epoch - 146ms/step
# Epoch 24/200
# 25/25 - 3s - loss: 0.4469 - accuracy: 0.8400 - val_loss: 0.4644 - val_accuracy: 0.7500 - 3s/epoch - 117ms/step
# Epoch 25/200
# 25/25 - 3s - loss: 0.3454 - accuracy: 0.8600 - val_loss: 0.1256 - val_accuracy: 1.0000 - 3s/epoch - 124ms/step
# Epoch 26/200
# 25/25 - 3s - loss: 0.3246 - accuracy: 0.8367 - val_loss: 0.4581 - val_accuracy: 0.7500 - 3s/epoch - 132ms/step
# Epoch 27/200
# 25/25 - 3s - loss: 0.3463 - accuracy: 0.8400 - val_loss: 0.3915 - val_accuracy: 0.8000 - 3s/epoch - 139ms/step
# Epoch 28/200
# 25/25 - 4s - loss: 0.4362 - accuracy: 0.8000 - val_loss: 0.7254 - val_accuracy: 0.6000 - 4s/epoch - 141ms/step
# Epoch 29/200
# 25/25 - 4s - loss: 0.4760 - accuracy: 0.7500 - val_loss: 0.6531 - val_accuracy: 0.8000 - 4s/epoch - 149ms/step
# Epoch 30/200
# 25/25 - 3s - loss: 0.4127 - accuracy: 0.8100 - val_loss: 0.3270 - val_accuracy: 0.8500 - 3s/epoch - 129ms/step
# Epoch 31/200
# 25/25 - 3s - loss: 0.3469 - accuracy: 0.8600 - val_loss: 0.1599 - val_accuracy: 1.0000 - 3s/epoch - 115ms/step
# Epoch 32/200
# 25/25 - 3s - loss: 0.2713 - accuracy: 0.8900 - val_loss: 0.5839 - val_accuracy: 0.8000 - 3s/epoch - 124ms/step
# Epoch 33/200
# 25/25 - 3s - loss: 0.4163 - accuracy: 0.8700 - val_loss: 0.3463 - val_accuracy: 0.8500 - 3s/epoch - 131ms/step
# Epoch 34/200
# 25/25 - 3s - loss: 0.4541 - accuracy: 0.8000 - val_loss: 0.3882 - val_accuracy: 0.9000 - 3s/epoch - 139ms/step
# Epoch 35/200
# 25/25 - 3s - loss: 0.4519 - accuracy: 0.7900 - val_loss: 0.6099 - val_accuracy: 0.7500 - 3s/epoch - 130ms/step
# Epoch 36/200
# 25/25 - 4s - loss: 0.3551 - accuracy: 0.8500 - val_loss: 0.6523 - val_accuracy: 0.7500 - 4s/epoch - 151ms/step
# Epoch 37/200
# 25/25 - 3s - loss: 0.4104 - accuracy: 0.8000 - val_loss: 0.4916 - val_accuracy: 0.8000 - 3s/epoch - 137ms/step
# Epoch 38/200
# 25/25 - 3s - loss: 0.2910 - accuracy: 0.8500 - val_loss: 0.6319 - val_accuracy: 0.6500 - 3s/epoch - 123ms/step
# Epoch 39/200
# 25/25 - 4s - loss: 0.3274 - accuracy: 0.8500 - val_loss: 0.5809 - val_accuracy: 0.7500 - 4s/epoch - 147ms/step
# Epoch 40/200
# 25/25 - 4s - loss: 0.4052 - accuracy: 0.8200 - val_loss: 0.4354 - val_accuracy: 0.9000 - 4s/epoch - 145ms/step
# Epoch 41/200
# 25/25 - 3s - loss: 0.3403 - accuracy: 0.8800 - val_loss: 0.2819 - val_accuracy: 0.9000 - 3s/epoch - 132ms/step
# Epoch 42/200
# 25/25 - 3s - loss: 0.3695 - accuracy: 0.8600 - val_loss: 0.4142 - val_accuracy: 0.9000 - 3s/epoch - 132ms/step
# Epoch 43/200
# 25/25 - 3s - loss: 0.2983 - accuracy: 0.9400 - val_loss: 0.3625 - val_accuracy: 0.8000 - 3s/epoch - 134ms/step
# Epoch 44/200
# 25/25 - 3s - loss: 0.3798 - accuracy: 0.8300 - val_loss: 0.2947 - val_accuracy: 0.9000 - 3s/epoch - 131ms/step
# Epoch 45/200
# 25/25 - 3s - loss: 0.4135 - accuracy: 0.8100 - val_loss: 0.3165 - val_accuracy: 0.8000 - 3s/epoch - 131ms/step
# Epoch 46/200
# 25/25 - 3s - loss: 0.3143 - accuracy: 0.8800 - val_loss: 0.4894 - val_accuracy: 0.7500 - 3s/epoch - 120ms/step
# Epoch 47/200
# 25/25 - 3s - loss: 0.5109 - accuracy: 0.7700 - val_loss: 0.2245 - val_accuracy: 0.9000 - 3s/epoch - 133ms/step
# Epoch 48/200
# 25/25 - 4s - loss: 0.3984 - accuracy: 0.8100 - val_loss: 0.2222 - val_accuracy: 0.9000 - 4s/epoch - 149ms/step
# Epoch 49/200
# 25/25 - 3s - loss: 0.4192 - accuracy: 0.8300 - val_loss: 0.3637 - val_accuracy: 0.8000 - 3s/epoch - 135ms/step
# Epoch 50/200
# 25/25 - 3s - loss: 0.3204 - accuracy: 0.8900 - val_loss: 0.6781 - val_accuracy: 0.8000 - 3s/epoch - 136ms/step
# Epoch 51/200
# 25/25 - 3s - loss: 0.3632 - accuracy: 0.8100 - val_loss: 0.6298 - val_accuracy: 0.7000 - 3s/epoch - 132ms/step
# Epoch 52/200
# 25/25 - 3s - loss: 0.3362 - accuracy: 0.8200 - val_loss: 0.2217 - val_accuracy: 0.9000 - 3s/epoch - 123ms/step
# Epoch 53/200
# 25/25 - 5s - loss: 0.3256 - accuracy: 0.8571 - val_loss: 0.4436 - val_accuracy: 0.8500 - 5s/epoch - 185ms/step
# Epoch 54/200
# 25/25 - 3s - loss: 0.4498 - accuracy: 0.7800 - val_loss: 0.3815 - val_accuracy: 0.8000 - 3s/epoch - 120ms/step
# Epoch 55/200
# 25/25 - 4s - loss: 0.3551 - accuracy: 0.8400 - val_loss: 0.3054 - val_accuracy: 0.7500 - 4s/epoch - 153ms/step
# Epoch 56/200
# 25/25 - 3s - loss: 0.3885 - accuracy: 0.8100 - val_loss: 0.3281 - val_accuracy: 0.8500 - 3s/epoch - 111ms/step
# Epoch 57/200
# 25/25 - 3s - loss: 0.3330 - accuracy: 0.8300 - val_loss: 0.4898 - val_accuracy: 0.8000 - 3s/epoch - 129ms/step
# Epoch 58/200
# 25/25 - 3s - loss: 0.3612 - accuracy: 0.8673 - val_loss: 0.5151 - val_accuracy: 0.7000 - 3s/epoch - 139ms/step
# Epoch 59/200
# 25/25 - 4s - loss: 0.2583 - accuracy: 0.9100 - val_loss: 0.4099 - val_accuracy: 0.7500 - 4s/epoch - 164ms/step
# Epoch 60/200
# 25/25 - 4s - loss: 0.4375 - accuracy: 0.7900 - val_loss: 0.2200 - val_accuracy: 0.9000 - 4s/epoch - 160ms/step
# Epoch 61/200
# 25/25 - 4s - loss: 0.4376 - accuracy: 0.7900 - val_loss: 0.3430 - val_accuracy: 0.9000 - 4s/epoch - 146ms/step
# Epoch 62/200
# 25/25 - 4s - loss: 0.4501 - accuracy: 0.8000 - val_loss: 0.2604 - val_accuracy: 0.8500 - 4s/epoch - 143ms/step
# Epoch 63/200
# 25/25 - 3s - loss: 0.3778 - accuracy: 0.8200 - val_loss: 0.4444 - val_accuracy: 0.7500 - 3s/epoch - 107ms/step
# Epoch 64/200
# 25/25 - 3s - loss: 0.3585 - accuracy: 0.8400 - val_loss: 0.8609 - val_accuracy: 0.7500 - 3s/epoch - 136ms/step
# Epoch 65/200
# 25/25 - 4s - loss: 0.3136 - accuracy: 0.8700 - val_loss: 0.3986 - val_accuracy: 0.9000 - 4s/epoch - 150ms/step
# Epoch 66/200
# 25/25 - 4s - loss: 0.3299 - accuracy: 0.8500 - val_loss: 0.9180 - val_accuracy: 0.6000 - 4s/epoch - 155ms/step
# Epoch 67/200
# 25/25 - 3s - loss: 0.3203 - accuracy: 0.8600 - val_loss: 0.4235 - val_accuracy: 0.8000 - 3s/epoch - 124ms/step
# Epoch 68/200
# 25/25 - 3s - loss: 0.2736 - accuracy: 0.8700 - val_loss: 0.3647 - val_accuracy: 0.8000 - 3s/epoch - 133ms/step
# Epoch 69/200
# 25/25 - 3s - loss: 0.3058 - accuracy: 0.8500 - val_loss: 0.4717 - val_accuracy: 0.8000 - 3s/epoch - 117ms/step
# Epoch 70/200
# 25/25 - 3s - loss: 0.4051 - accuracy: 0.8000 - val_loss: 0.3924 - val_accuracy: 0.8500 - 3s/epoch - 130ms/step
# Epoch 71/200
# 25/25 - 3s - loss: 0.3173 - accuracy: 0.8600 - val_loss: 0.7111 - val_accuracy: 0.7500 - 3s/epoch - 132ms/step
# Epoch 72/200
# 25/25 - 4s - loss: 0.3637 - accuracy: 0.8300 - val_loss: 0.5412 - val_accuracy: 0.8000 - 4s/epoch - 179ms/step
# Epoch 73/200
# 25/25 - 3s - loss: 0.3939 - accuracy: 0.8200 - val_loss: 0.3329 - val_accuracy: 0.8000 - 3s/epoch - 133ms/step
# Epoch 74/200
# 25/25 - 5s - loss: 0.3591 - accuracy: 0.8700 - val_loss: 0.7261 - val_accuracy: 0.8500 - 5s/epoch - 184ms/step
# Epoch 75/200
# 25/25 - 3s - loss: 0.3655 - accuracy: 0.8400 - val_loss: 0.3699 - val_accuracy: 0.7500 - 3s/epoch - 110ms/step
# Epoch 76/200
# 25/25 - 3s - loss: 0.3061 - accuracy: 0.8400 - val_loss: 0.2596 - val_accuracy: 0.9500 - 3s/epoch - 129ms/step
# Epoch 77/200
# 25/25 - 3s - loss: 0.4403 - accuracy: 0.8100 - val_loss: 0.2915 - val_accuracy: 0.8500 - 3s/epoch - 129ms/step
# Epoch 78/200
# 25/25 - 4s - loss: 0.3681 - accuracy: 0.8100 - val_loss: 0.2772 - val_accuracy: 0.9500 - 4s/epoch - 154ms/step
# Epoch 79/200
# 25/25 - 3s - loss: 0.3787 - accuracy: 0.8100 - val_loss: 0.2637 - val_accuracy: 0.9500 - 3s/epoch - 130ms/step
# Epoch 80/200
# 25/25 - 3s - loss: 0.3156 - accuracy: 0.8500 - val_loss: 0.2286 - val_accuracy: 0.8500 - 3s/epoch - 132ms/step
# Epoch 81/200
# 25/25 - 4s - loss: 0.3593 - accuracy: 0.8400 - val_loss: 0.5060 - val_accuracy: 0.7500 - 4s/epoch - 158ms/step
# Epoch 82/200
# 25/25 - 4s - loss: 0.3699 - accuracy: 0.8500 - val_loss: 0.2772 - val_accuracy: 0.8500 - 4s/epoch - 142ms/step
# Epoch 83/200
# 25/25 - 3s - loss: 0.4073 - accuracy: 0.8100 - val_loss: 0.4911 - val_accuracy: 0.7500 - 3s/epoch - 108ms/step
# Epoch 84/200
# 25/25 - 3s - loss: 0.3763 - accuracy: 0.8400 - val_loss: 0.6438 - val_accuracy: 0.7000 - 3s/epoch - 140ms/step
# Epoch 85/200
# 25/25 - 5s - loss: 0.4470 - accuracy: 0.7300 - val_loss: 0.1872 - val_accuracy: 0.9500 - 5s/epoch - 187ms/step
# Epoch 86/200
# 25/25 - 5s - loss: 0.2980 - accuracy: 0.9000 - val_loss: 0.4227 - val_accuracy: 0.8000 - 5s/epoch - 190ms/step
# Epoch 87/200
# 25/25 - 4s - loss: 0.3163 - accuracy: 0.8800 - val_loss: 0.5432 - val_accuracy: 0.7500 - 4s/epoch - 149ms/step
# Epoch 88/200
# 25/25 - 5s - loss: 0.2861 - accuracy: 0.8500 - val_loss: 0.3362 - val_accuracy: 0.8500 - 5s/epoch - 214ms/step
# Epoch 89/200
# 25/25 - 3s - loss: 0.2926 - accuracy: 0.8600 - val_loss: 0.5533 - val_accuracy: 0.7500 - 3s/epoch - 126ms/step
# Epoch 90/200
# 25/25 - 5s - loss: 0.2483 - accuracy: 0.8900 - val_loss: 0.3815 - val_accuracy: 0.8500 - 5s/epoch - 189ms/step
# Epoch 91/200
# 25/25 - 4s - loss: 0.4042 - accuracy: 0.8000 - val_loss: 0.2235 - val_accuracy: 0.9000 - 4s/epoch - 140ms/step
# Epoch 92/200
# 25/25 - 3s - loss: 0.2429 - accuracy: 0.9200 - val_loss: 0.3772 - val_accuracy: 0.8000 - 3s/epoch - 134ms/step
# Epoch 93/200
# 25/25 - 4s - loss: 0.5142 - accuracy: 0.8100 - val_loss: 0.5229 - val_accuracy: 0.8000 - 4s/epoch - 142ms/step
# Epoch 94/200
# 25/25 - 4s - loss: 0.3456 - accuracy: 0.8500 - val_loss: 0.5019 - val_accuracy: 0.8500 - 4s/epoch - 156ms/step
# Epoch 95/200
# 25/25 - 3s - loss: 0.3940 - accuracy: 0.8300 - val_loss: 0.3124 - val_accuracy: 0.8000 - 3s/epoch - 132ms/step
# Epoch 96/200
# 25/25 - 4s - loss: 0.2395 - accuracy: 0.9000 - val_loss: 0.5033 - val_accuracy: 0.9500 - 4s/epoch - 148ms/step
# Epoch 97/200
#
# Training Model Stopped! Accuracy Model is above 90%!
# 25/25 - 3s - loss: 0.2522 - accuracy: 0.9200 - val_loss: 0.1033 - val_accuracy: 1.0000 - 3s/epoch - 118ms/step

# %%
# melihat hasil dari model yang telah Anda buat pada Notebook. 
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  
  print(fn)
  if classes==0:
    print('bersih')
  else:
    print('kotor')
# Out:
#      <input type="file" id="files-8e3d69e1-453b-4203-b7d1-014fa0b0c7e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e3d69e1-453b-4203-b7d1-014fa0b0c7e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2021-11-23 at 11.16.36.jpeg to WhatsApp Image 2021-11-23 at 11.16.36 (1).jpeg
# WhatsApp Image 2021-11-23 at 11.16.36.jpeg
# bersih

# %%
# melihat hasil dari model yang telah Anda buat pada Notebook. 
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  
  print(fn)
  if classes==0:
    print('bersih')
  else:
    print('kotor')
# Out:
#      <input type="file" id="files-933edaba-f901-4db0-932a-62e1881c77af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-933edaba-f901-4db0-932a-62e1881c77af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dirty1.jpg to dirty1 (1).jpg
# dirty1.jpg
# kotor

# %%
# METRIK EVALUSASI
# MEMBUAT PLOT AKURASI dan LOSS TRAINING DAN VALIDATION
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# Menyimpan Model ke Format TF-Lite
# Mengkonversi Model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Menyimpan Model
with open('model_deteksi.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp_0hogrrq/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
# SAVE MODEL TO JSON
from keras.models import model_from_json

# serialize model to JSON
model_json = model.to_json()

with open("model_deteksi.json", "w") as json_file:
    json_file.write(model_json)

# save weights to HDF5
model.save_weights("model_deteksi.h5")
print("Model saved")
# Out:
# Model saved
